# %% [markdown]
# <a href="https://colab.research.google.com/github/taruarora/ML-DL/blob/main/logistic_regression_titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns

# %%
df=pd.read_csv()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sn.heatmap(data=df, annot=annot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5c1d28f7ab4c> in <module>
# ----> 1 plt.pcolor(df)
#
# NameError: name 'plt' is not defined

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#chiscore
#boxplot
#violin plot for distribution
#kfold
#age ko predict
#svm decision tree random forest
#bagging and boosting
#gra

# %%
df[df['Embarked']=='s']=1

# %%
#we cannot have data entry as string we need to get them to number
#labelencoder is used
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
#d=['Name','Sex','Ticket','Cabin']
#name and ticket are of no use so we can drop them
d=['Sex','Cabin','Embarked']
for i in d:
  df[i]=le.fit_transform(df[i])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
sns.countplot(x="Survived",data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
df=df.drop('Cabin',axis='columns')
df
#bcoz majority values are NaN
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (714, 11)

# %%
df.drop(['Name','Ticket'],axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0              1         0       3    1  22.0      1      0   7.2500         2
# 1              2         1       1    0  38.0      1      0  71.2833         0
# 2              3         1       3    0  26.0      0      0   7.9250         2
# 3              4         1       1    0  35.0      1      0  53.1000         2
# 4              5         0       3    1  35.0      0      0   8.0500         2
# ..           ...       ...     ...  ...   ...    ...    ...      ...       ...
# 885          886         0       3    0  39.0      0      5  29.1250         1
# 886          887         0       2    1  27.0      0      0  13.0000         2
# 887          888         1       1    0  19.0      0      0  30.0000         2
# 889          890         1       1    1  26.0      0      0  30.0000         0
# 890          891         0       3    1  32.0      0      0   7.7500         1
#
# [714 rows x 9 columns]

# %%
#while looking at data we can see ki sex->male toh it is 1 else u can use dummies
#df.corr() not for categoroca;
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000  0.029340 -0.035349  0.024575  0.036847 -0.082398
# Survived        0.029340  1.000000 -0.359653 -0.538826 -0.077221 -0.017358
# Pclass         -0.035349 -0.359653  1.000000  0.155460 -0.369226  0.067247
# Sex             0.024575 -0.538826  0.155460  1.000000  0.093254 -0.103950
# Age             0.036847 -0.077221 -0.369226  0.093254  1.000000 -0.308247
# SibSp          -0.082398 -0.017358  0.067247 -0.103950 -0.308247  1.000000
# Parch          -0.011617  0.093317  0.025683 -0.246972 -0.189119  0.383820
# Fare            0.009592  0.268189 -0.554182 -0.184994  0.096067  0.138329
# Embarked       -0.001873 -0.174692  0.234857  0.102239 -0.025252  0.030121
#
#                 Parch      Fare  Embarked
# PassengerId -0.011617  0.009592 -0.001873
# Survived     0.093317  0.268189 -0.174692
# Pclass       0.025683 -0.554182  0.234857
# Sex         -0.246972 -0.184994  0.102239
# ...

# %%
sns.pairplot(df)

# %%
target=df['Survived']
df=df.drop('Survived',axis='columns')
df
# Out:
#      PassengerId  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0              1       3    1  22.0      1      0   7.2500         2
# 1              2       1    0  38.0      1      0  71.2833         0
# 2              3       3    0  26.0      0      0   7.9250         2
# 3              4       1    0  35.0      1      0  53.1000         2
# 4              5       3    1  35.0      0      0   8.0500         2
# ..           ...     ...  ...   ...    ...    ...      ...       ...
# 885          886       3    0  39.0      0      5  29.1250         1
# 886          887       2    1  27.0      0      0  13.0000         2
# 887          888       1    0  19.0      0      0  30.0000         2
# 889          890       1    1  26.0      0      0  30.0000         0
# 890          891       3    1  32.0      0      0   7.7500         1
#
# [714 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(df,target,random_state=42)

# %%
X_train.shape
X_test.shape
# Out:
# (179, 8)

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()
model.fit(X_train,Y_train)

#this proves all the values need to be numerical
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
score=model.score(X_test,Y_test)
score
# Out:
# 0.7653631284916201

# %%
plt.plot(X_test,y_pred,color="red")
plt.plot(X_test,Y_test,color="blue")
plt.legend()
plt.show()
plt.close()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81       115
#            1       0.65      0.73      0.69        64
#
#     accuracy                           0.77       179
#    macro avg       0.75      0.76      0.75       179
# weighted avg       0.77      0.77      0.77       179

# %%
df=df.drop(['Embarked','PassengerId'],axis='columns')

# %%
#confusion matrix

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(df,target,random_state=42)

# %%
X_train.shape
X_test.shape
# Out:
# (179, 6)

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()
model.fit(X_train,Y_train)

#this proves all the values need to be numerical
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
score=model.score(X_test,Y_test)
score
# Out:
# 0.770949720670391

# %%
plt.plot(X_test,y_pred,color="red")
plt.plot(X_test,Y_test,color="blue")
plt.legend()
plt.show()
plt.close()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.82       116
#            1       0.65      0.75      0.70        63
#
#     accuracy                           0.77       179
#    macro avg       0.75      0.77      0.76       179
# weighted avg       0.78      0.77      0.77       179
